# %% [markdown]
# # Stock Price Prediction Using Linear Regression

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_csv("/kaggle/input/2023-paytm/Quote-Equity-PAYTM-EQ-18-11-2022-to-18-11-2023.csv")
data1= pd.read_csv("/kaggle/input/tesla-latest-stock-data-2010-2020/TSLA.csv")

# %% [markdown]
# ### Let's See The Data

# %%
data.head()
print("ajbdahbda")
data1.head()
# Out:
# ajbdahbda
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 1  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 3  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# 4  2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500

# %%
data.info()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           249 non-null    object
#  1   series         249 non-null    object
#  2   OPEN           249 non-null    float64
#  3   HIGH           249 non-null    float64
#  4   LOW            249 non-null    float64
#  5   PREV. CLOSE    249 non-null    float64
#  6   ltp            249 non-null    float64
#  7   close          249 non-null    float64
#  8   vwap           249 non-null    float64
#  9   52W H          249 non-null    object
#  10  52W L          249 non-null    float64
#  11  VOLUME         249 non-null    object
#  12  VALUE          249 non-null    object
#  13  No of trades   249 non-null    object
# dtypes: float64(8), object(6)
# memory usage: 27.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# ...

# %%
data.describe()
# Out:
#             OPEN        HIGH         LOW   PREV. CLOSE         ltp   \
# count  249.000000  249.000000  249.000000    249.000000  249.000000
# mean   722.683133  735.084137  709.435542    719.593976  720.504618
# std    147.671945  148.631227  145.151500    147.591037  147.258333
# min    444.000000  467.000000  438.350000    441.100000  441.150000
# 25%    586.850000  605.400000  575.800000    580.750000  582.800000
# 50%    710.700000  723.000000  701.500000    708.550000  709.700000
# 75%    860.000000  871.450000  850.000000    857.350000  857.500000
# max    987.000000  998.300000  961.900000    987.650000  980.050000
#
#            close        vwap       52W L
# count  249.000000  249.000000  249.000000
# mean   720.993976  722.160161  439.070281
# std    147.532035  146.765716    6.793320
# min    441.100000  452.310000  438.350000
# 25%    583.900000  593.310000  438.350000
# 50%    709.550000  712.320000  438.350000
# 75%    857.400000  856.670000  438.350000
# ...

# %%
data1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2579.000000  2579.000000  2579.000000  2579.000000  2579.000000
# mean     49.206686    50.301806    48.073117    49.253279    49.253279
# std      57.934102    59.888383    55.852349    58.119783    58.119783
# min       3.228000     3.326000     2.996000     3.160000     3.160000
# 25%       7.159000     7.268000     6.989000     7.153000     7.153000
# 50%      44.001999    44.660000    43.301998    43.924000    43.924000
# 75%      59.339000    60.171000    57.841000    59.020001    59.020001
# max     502.140015   502.489990   470.510010   498.320007   498.320007
#
#              Volume
# count  2.579000e+03
# mean   3.078217e+07
# std    2.855717e+07
# min    5.925000e+05
# 25%    1.047400e+07
# 50%    2.413100e+07
# 75%    3.979150e+07
# max    3.046940e+08

# %%
print(data.head())
# Out:
#          Date  series    OPEN    HIGH    LOW   PREV. CLOSE    ltp   close   \
# 0  17-Nov-2023      EQ  892.95  893.30  870.9        905.35  887.0  888.40
# 1  16-Nov-2023      EQ  920.00  922.85  898.0        919.10  904.0  905.35
# 2  15-Nov-2023      EQ  915.00  924.95  903.9        894.65  914.8  919.10
# 3  13-Nov-2023      EQ  891.00  899.00  891.0        894.80  894.7  894.65
# 4  12-Nov-2023      EQ  902.00  905.00  888.7        894.15  889.8  894.80
#
#     vwap   52W H   52W L     VOLUME              VALUE  No of trades
# 0  883.18  998.30  438.35  55,42,250  4,89,48,20,843.55      1,76,622
# 1  909.96  998.30  438.35  27,98,897  2,54,68,91,970.25        73,431
# 2  913.82  998.30  438.35  38,02,638  3,47,49,39,055.50      1,06,542
# 3  894.88  998.30  438.35   8,60,179    76,97,60,712.75        36,558
# 4  896.93  998.30  438.35   3,23,914    29,05,28,326.30        10,408

# %%
x=data1[['High', 'Low', 'Open']].values

# %%
data.head()
# Out:
#          Date  series    OPEN    HIGH    LOW   PREV. CLOSE    ltp   close   \
# 0  17-Nov-2023      EQ  892.95  893.30  870.9        905.35  887.0  888.40
# 1  16-Nov-2023      EQ  920.00  922.85  898.0        919.10  904.0  905.35
# 2  15-Nov-2023      EQ  915.00  924.95  903.9        894.65  914.8  919.10
# 3  13-Nov-2023      EQ  891.00  899.00  891.0        894.80  894.7  894.65
# 4  12-Nov-2023      EQ  902.00  905.00  888.7        894.15  889.8  894.80
#
#     vwap   52W H   52W L     VOLUME              VALUE  No of trades
# 0  883.18  998.30  438.35  55,42,250  4,89,48,20,843.55      1,76,622
# 1  909.96  998.30  438.35  27,98,897  2,54,68,91,970.25        73,431
# 2  913.82  998.30  438.35  38,02,638  3,47,49,39,055.50      1,06,542
# 3  894.88  998.30  438.35   8,60,179    76,97,60,712.75        36,558
# 4  896.93  998.30  438.35   3,23,914    29,05,28,326.30        10,408

# %%
# X_paytm = data[['OPEN', 'HIGH', 'LOW']].values
print(data.index)
# X_paytm = data[['HIGH', 'LOW', 'OPEN']].values
# y_paytm = data['close'].values
# Out:
# RangeIndex(start=0, stop=249, step=1)

# %%
import pandas as pd
print(data.info())



X_paytm = data[['HIGH', 'LOW', 'OPEN']].values
y_paytm = data['close'].values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           249 non-null    object
#  1   series         249 non-null    object
#  2   OPEN           249 non-null    float64
#  3   HIGH           249 non-null    float64
#  4   LOW            249 non-null    float64
#  5   PREV. CLOSE    249 non-null    float64
#  6   ltp            249 non-null    float64
#  7   close          249 non-null    float64
#  8   vwap           249 non-null    float64
#  9   52W H          249 non-null    object
#  10  52W L          249 non-null    float64
#  11  VOLUME         249 non-null    object
#  12  VALUE          249 non-null    object
#  13  No of trades   249 non-null    object
# dtypes: float64(8), object(6)
# memory usage: 27.4+ KB
# None
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Separate the Input and Output Columns

# %%
X = data[['HIGH','LOW','OPEN']].values
y = data['close'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-a417ff511435> in <module>
# ----> 1 X = data[['HIGH','LOW','OPEN']].values
#       2 y = data['close'].values
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b5fec669aca1> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
y

# %% [markdown]
# ### Spliting the Train and Test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-794c87773c17> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=1)
#
# NameError: name 'X' is not defined

# %% [markdown]
# ### Linear Regression Model

# %%
regressor = LinearRegression()

# %% [markdown]
# ### Fitting the data in the Model

# %%
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-cb9aa30858d7> in <module>
# ----> 1 regressor.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
print(regressor.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2670e6642edd> in <module>
# ----> 1 print(regressor.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
print(regressor.intercept_)

# %% [markdown]
# ### Prediction

# %%
predicted = regressor.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f77ec2ec81e8> in <module>
# ----> 1 predicted = regressor.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
print(predicted)

# %% [markdown]
# ### Combine the Actual and Predicted data

# %%
data1 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted' : predicted.flatten()})

# %%
data1.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-86bae4b249ee> in <module>
# ----> 1 data1.head(20)
#
# NameError: name 'data1' is not defined

# %% [markdown]
# ### Mean Absolute Error

# %%
import math
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:', metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:', math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-9f7b246f78a0> in <module>
#       1 import math
# ----> 2 print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,predicted))
#       3 print('Mean Squared Error:', metrics.mean_squared_error(y_test,predicted))
#       4 print('Root Mean Squared Error:', math.sqrt(metrics.mean_squared_error(y_test,predicted)))
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ### Plotting Graph

# %%
graph = data1.head(20)

# %%
graph.plot(kind='bar')

# %% [markdown]
# #### I hope you liked my notebook.
