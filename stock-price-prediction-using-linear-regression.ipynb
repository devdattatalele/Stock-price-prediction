# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Quote-Equity-PAYTM-EQ-18-11-2022-to-18-11-2023.csv")

# %%
data.head()
#print("ajbdahbda")
# Out:
# ajbdahbda

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           249 non-null    object
#  1   series         249 non-null    object
#  2   OPEN           249 non-null    float64
#  3   HIGH           249 non-null    float64
#  4   LOW            249 non-null    float64
#  5   PREV. CLOSE    249 non-null    float64
#  6   ltp            249 non-null    float64
#  7   close          249 non-null    float64
#  8   vwap           249 non-null    float64
#  9   52W H          249 non-null    object
#  10  52W L          249 non-null    float64
#  11  VOLUME         249 non-null    object
#  12  VALUE          249 non-null    object
#  13  No of trades   249 non-null    object
# dtypes: float64(8), object(6)
# memory usage: 27.4+ KB

# %%
data.describe()
# Out:
#             OPEN        HIGH         LOW   PREV. CLOSE         ltp   \
# count  249.000000  249.000000  249.000000    249.000000  249.000000
# mean   722.683133  735.084137  709.435542    719.593976  720.504618
# std    147.671945  148.631227  145.151500    147.591037  147.258333
# min    444.000000  467.000000  438.350000    441.100000  441.150000
# 25%    586.850000  605.400000  575.800000    580.750000  582.800000
# 50%    710.700000  723.000000  701.500000    708.550000  709.700000
# 75%    860.000000  871.450000  850.000000    857.350000  857.500000
# max    987.000000  998.300000  961.900000    987.650000  980.050000
#
#            close        vwap       52W L
# count  249.000000  249.000000  249.000000
# mean   720.993976  722.160161  439.070281
# std    147.532035  146.765716    6.793320
# min    441.100000  452.310000  438.350000
# 25%    583.900000  593.310000  438.350000
# 50%    709.550000  712.320000  438.350000
# 75%    857.400000  856.670000  438.350000
# max    987.650000  983.390000  510.050000

# %%
print(data.head())
# Out:
#          Date  series    OPEN    HIGH    LOW   PREV. CLOSE    ltp   close   \
# 0  17-Nov-2023      EQ  892.95  893.30  870.9        905.35  887.0  888.40
# 1  16-Nov-2023      EQ  920.00  922.85  898.0        919.10  904.0  905.35
# 2  15-Nov-2023      EQ  915.00  924.95  903.9        894.65  914.8  919.10
# 3  13-Nov-2023      EQ  891.00  899.00  891.0        894.80  894.7  894.65
# 4  12-Nov-2023      EQ  902.00  905.00  888.7        894.15  889.8  894.80
#
#     vwap   52W H   52W L     VOLUME              VALUE  No of trades
# 0  883.18  998.30  438.35  55,42,250  4,89,48,20,843.55      1,76,622
# 1  909.96  998.30  438.35  27,98,897  2,54,68,91,970.25        73,431
# 2  913.82  998.30  438.35  38,02,638  3,47,49,39,055.50      1,06,542
# 3  894.88  998.30  438.35   8,60,179    76,97,60,712.75        36,558
# 4  896.93  998.30  438.35   3,23,914    29,05,28,326.30        10,408

# %%
data.head()
# Out:
#          Date  series    OPEN    HIGH    LOW   PREV. CLOSE    ltp   close   \
# 0  17-Nov-2023      EQ  892.95  893.30  870.9        905.35  887.0  888.40
# 1  16-Nov-2023      EQ  920.00  922.85  898.0        919.10  904.0  905.35
# 2  15-Nov-2023      EQ  915.00  924.95  903.9        894.65  914.8  919.10
# 3  13-Nov-2023      EQ  891.00  899.00  891.0        894.80  894.7  894.65
# 4  12-Nov-2023      EQ  902.00  905.00  888.7        894.15  889.8  894.80
#
#     vwap   52W H   52W L     VOLUME              VALUE  No of trades
# 0  883.18  998.30  438.35  55,42,250  4,89,48,20,843.55      1,76,622
# 1  909.96  998.30  438.35  27,98,897  2,54,68,91,970.25        73,431
# 2  913.82  998.30  438.35  38,02,638  3,47,49,39,055.50      1,06,542
# 3  894.88  998.30  438.35   8,60,179    76,97,60,712.75        36,558
# 4  896.93  998.30  438.35   3,23,914    29,05,28,326.30        10,408

# %%
import pandas as pd
print(data.info())



X_paytm = data[['HIGH ', 'LOW ', 'OPEN ']].values
y_paytm = data['close '].values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           249 non-null    object
#  1   series         249 non-null    object
#  2   OPEN           249 non-null    float64
#  3   HIGH           249 non-null    float64
#  4   LOW            249 non-null    float64
#  5   PREV. CLOSE    249 non-null    float64
#  6   ltp            249 non-null    float64
#  7   close          249 non-null    float64
#  8   vwap           249 non-null    float64
#  9   52W H          249 non-null    object
#  10  52W L          249 non-null    float64
#  11  VOLUME         249 non-null    object
#  12  VALUE          249 non-null    object
#  13  No of trades   249 non-null    object
# dtypes: float64(8), object(6)
# memory usage: 27.4+ KB
# None

# %%
X_paytm_train, X_paytm_test, y_paytm_train, y_paytm_test = train_test_split(X_paytm,y_paytm, test_size=0.3, random_state=1)

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_paytm_train, y_paytm_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [ 0.58505384  0.89594517 -0.47153437]

# %%
print(regressor.intercept_)
# Out:
# -4.013858063609973

# %%
predicted = regressor.predict(X_paytm_test)

# %%
print(predicted)
# Out:
# [855.94985606 535.84552993 566.40661385 628.22740097 855.26929837
#  477.05271573 909.32418424 532.73681814 610.98548948 896.36232918
#  478.5230587  665.92545411 702.62276282 622.87518845 722.73678354
#  783.36060991 629.83533904 855.73386957 940.90515763 773.94941485
#  508.40116699 854.69395185 854.45404953 642.87907705 710.31353285
#  706.79125343 447.87863575 529.43913804 845.73041416 514.95211249
#  519.93226241 839.23774062 863.91091361 548.05647717 622.9345361
#  527.64255714 845.05238058 857.36033578 900.46200263 538.48198829
#  533.98500554 984.58458462 856.95161137 876.67604567 861.19803068
#  804.89692749 855.94876982 921.73481    925.64577065 877.83676141
#  526.17637153 858.87466969 724.40477983 640.59303193 607.01031229
#  696.40665268 700.4328921  904.74597471 879.01438292 691.65653603
#  612.22312729 649.70847106 616.45433498 649.42227047 903.70433844
#  530.27565128 856.70103963 585.82919525 667.93735681 837.78499228
#  809.80385143 540.33235344 610.67387635 641.08805259 624.0453059 ]

# %%
data1 = pd.DataFrame({'Actual': y_paytm_test.flatten(), 'Predicted' : predicted.flatten()})

# %%
import math
print('Mean Absolute Error:', metrics.mean_absolute_error(y_paytm_test,predicted))
print('Mean Squared Error:', metrics.mean_squared_error(y_paytm_test,predicted))
print('Root Mean Squared Error:', math.sqrt(metrics.mean_squared_error(y_paytm_test,predicted)))
# Out:
# Mean Absolute Error: 3.993277306009316
# Mean Squared Error: 29.71555261571667
# Root Mean Squared Error: 5.451197356151828

# %%
graph = data.head(20)

# %%
graph.plot(kind='bar')
# Out:
# <Axes: >

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=data['Date '],
                open=data['OPEN '],
                high=data['HIGH '],
                low=data['LOW '],
                close=data['close '])])

fig.update_layout(title='Stock Price  Chart', xaxis_title='Date', yaxis_title='Price')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="72167c7f-e182-4d72-9d35-373f938c8ddd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72167c7f-e182-4d72-9d35-373f938c8ddd")) {                    Plotly.newPlot(                        "72167c7f-e182-4d72-9d35-373f938c8ddd",                        [{"close":[888.4,905.35,919.1,894.65,894.8,894.15,894.55,896.15,881.65,880.65,904.05,921.25,913.35,920.75,922.6,896.35,875.95,916.5,923.7,987.65,968.45,947.95,941.55,937.85,933.1,957.55,971.75,949.7,905.2,928.3,895.1,863.1,876.6,857.7,854.4,853.2,852.3,848.45,850.0,841.05,853.35,873.2,885.15,856.55,838.25,864.55,904.4,905.4,894.35,898.8,881.1,856.7,857.4,853.9,861.75,852.9,882.8,899.2,904.45,904.75,857.35,837.